# %%
import matplotlib.pyplot as plt
import pickle

# %%
merged = pickle.load(open('../code/experimental-notebooks/df_to_plot', 'rb'))
# Out:
# /home/ilana/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
merged.head()
# Out:
#    LGL_ADMIN_AREA_ID                          ADMIN_AREA_NAME  \
# 0                  2     Regional District of Bulkley-Nechako
# 1                 18                Cariboo Regional District
# 2                 18                Cariboo Regional District
# 3                 35  Regional District of Fraser-Fort George
# 4                 47     Regional District of Kitimat-Stikine
#
#   ADMIN_AREA_ABBREVIATION ADMIN_AREA_BOUNDARY_TYPE    ADMIN_AREA_TYPE  \
# 0                    RDBN                    Legal  Regional District
# 1                     CRD                    Legal  Regional District
# 2                     CRD                    Legal  Regional District
# 3                   RDFFG                    Legal  Regional District
# 4                    RDKS                    Legal  Regional District
#
#           ADMIN_AREA_GROUP_NAME CHANGE_REQUESTED_ORG UPDATE_TYPE WHEN_UPDATED  \
# 0  Province of British Columbia                MCSCD           E     20130606
# ...

# %%
# set the value column that will be visualised
variable = 'Total Damage'
# set the range for the choropleth values
vmin, vmax = 0, 1000000000
# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(55, 15))
# remove the axis
ax.axis('off')
# add a title and annotation
ax.set_title('Median %s per Registry'%variable, fontdict={'fontsize': '40', 'fontweight' : '3'})
ax.annotate('Source: Classification of Lexis Nexis Negligence Cases from 2000 to 2019', xy=(0.5, .05), xycoords='figure fraction', fontsize=20, color='#555555')
# Create colorbar legend
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# empty array for the data range
sm.set_array([]) # or alternatively sm._A = []. Not sure why this step is necessary, but many recommends it
# add the colorbar to the figure
fig.colorbar(sm)
# create map

# for idx, row in merged.iterrows():
#     ax.annotate(s=row['city'], xy=(row['lat'], row['lng']),horizontalalignment='center')

merged.plot(column = variable, cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8')

# %% [markdown]
# ```# for idx, row in merged.iterrows():
# #     ax.annotate(s=row['city'], xy=(row['lat'], row['lng']),horizontalalignment='center')```
